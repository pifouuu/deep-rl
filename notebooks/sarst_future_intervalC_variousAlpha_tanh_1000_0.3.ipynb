# %%
# %matplotlib inline
import json
import numpy as np
import glob
import matplotlib.pyplot as plt
import brewer2mpl
import math
import pandas as pd
import json_tricks

# %%
LOGDIR = '../results/'
PARAMS = ['sarst_future_intervalC_0.5_inf_tanh_True_True_1000_0.3',
          'sarst_future_intervalC_1_inf_tanh_True_True_1000_0.3',
          'sarst_future_intervalC_2_inf_tanh_True_True_1000_0.3',
]

# %%
frames = []
for PARAM in PARAMS:
    res_steps = glob.glob(LOGDIR + PARAM + '/*/' + 'log_steps/progress.json')
    for num_run, run in enumerate(res_steps):
        try:
            df = pd.read_json(run, lines=True)
        except ValueError:
            print("run "+run+": invalid")
        df['params'] = PARAM
        df['num_run']=num_run
        frames.append(df)
expe_res_steps = pd.concat(frames, ignore_index=True)
expe_res_steps
# Out:
#        Test reward on initial goal  Test reward on random goal  critic_loss  \
# 0                              NaN                         NaN     0.000296
# 1                              NaN                         NaN     0.000020
# 2                              NaN                         NaN     0.000012
# 3                              NaN                         NaN     0.000004
# 4                        -0.012535                   -0.383272     0.000005
# 5                        -0.012535                   -0.383272     0.000029
# 6                        -0.012535                   -0.383272     0.000020
# 7                        -0.012535                   -0.383272     0.000072
# 8                        -0.012535                   -0.383272     5.023680
# 9                        -8.720329                   -3.858447     3.496155
# 10                       -8.720329                   -3.858447     4.564281
# 11                       -8.720329                   -3.858447     4.127813
# 12                       -8.720329                   -3.858447     1.505978
# 13                       -8.720329                   -3.858447     2.599072
# 14                      -93.893991                  -51.234446     4.409952
# 15                      -93.893991                  -51.234446     5.039753
# 16                      -93.893991                  -51.234446     3.873935
# 17                      -93.893991                  -51.234446     3.803526
# 18                      -93.893991                  -51.234446     3.386357
# 19                      -99.720231                  -77.301464     3.724984
# 20                      -99.720231                  -77.301464     2.680159
# 21                      -99.720231                  -77.301464     3.357242
# 22                      -99.720231                  -77.301464     3.279312
# 23                      -99.720231                  -77.301464     4.555984
# 24                      -99.950615                  -37.674772     5.947503
# 25                      -99.950615                  -37.674772     1.874245
# 26                      -99.950615                  -37.674772     6.394449
# 27                      -99.950615                  -37.674772     2.955605
# 28                      -99.950615                  -37.674772     3.146419
# 29                      -99.991034                  -48.870090     3.696473
# ...                            ...                         ...          ...
# 99970                    94.664020                   96.120754     0.534487
# 99971                    94.664020                   96.120754     0.459963
# 99972                    94.664020                   96.120754     0.491242
# 99973                    94.664020                   96.120754     0.819194
# 99974                    94.140148                   96.029564     0.679548
# 99975                    94.140148                   96.029564     0.487355
# 99976                    94.140148                   96.029564     0.597210
# 99977                    94.140148                   96.029564     0.660560
# 99978                    94.140148                   96.029564     0.575166
# 99979                    94.426898                   95.799445     0.573123
# 99980                    94.426898                   95.799445     0.441965
# 99981                    94.426898                   95.799445     0.679263
# 99982                    94.426898                   95.799445     0.600531
# 99983                    94.426898                   95.799445     0.612095
# 99984                    94.429206                   95.831388     0.529464
# 99985                    94.429206                   95.831388     0.652180
# 99986                    94.429206                   95.831388     0.420335
sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99982  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99983  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99984  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99985  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99986  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99987  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99988  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99989  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99990  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99991  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99992  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99993  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99994  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99995  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99996  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99997  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99998  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
# 99999  sarst_future_intervalC_0.5_inf_linear_True_Tru...       19
#
# [100000 rows x 11 columns]

# %%
means_steps = expe_res_steps.groupby(['training_step','params']).mean()
means_steps.reset_index(level=['training_step', 'params'], inplace=True)
means_steps
# Out:
#       training_step                                             params  \
# 0               200  sarst_future_intervalC_0.5_inf_linear_True_Tru...
# 1               200  sarst_future_intervalC_0.5_inf_tanh_True_True_...
# 2               200  sarst_future_intervalC_1_inf_tanh_True_True_10...
# 3               200  sarst_future_intervalC_2_inf_linear_True_True_...
# 4               200  sarst_future_intervalC_2_inf_tanh_True_True_10...
# 5               400  sarst_future_intervalC_0.5_inf_linear_True_Tru...
# 6               400  sarst_future_intervalC_0.5_inf_tanh_True_True_...
# 7               400  sarst_future_intervalC_1_inf_tanh_True_True_10...
# 8               400  sarst_future_intervalC_2_inf_linear_True_True_...
# 9               400  sarst_future_intervalC_2_inf_tanh_True_True_10...
# 10              600  sarst_future_intervalC_0.5_inf_linear_True_Tru...
# 11              600  sarst_future_intervalC_0.5_inf_tanh_True_True_...
# 12              600  sarst_future_intervalC_1_inf_tanh_True_True_10...
# 13              600  sarst_future_intervalC_2_inf_linear_True_True_...
# 14              600  sarst_future_intervalC_2_inf_tanh_True_True_10...
# 15              800  sarst_future_intervalC_0.5_inf_linear_True_Tru...
# 16              800  sarst_future_intervalC_0.5_inf_tanh_True_True_...
# 17              800  sarst_future_intervalC_1_inf_tanh_True_True_10...
# 18              800  sarst_future_intervalC_2_inf_linear_True_True_...
# 19              800  sarst_future_intervalC_2_inf_tanh_True_True_10...
# 20             1000  sarst_future_intervalC_0.5_inf_linear_True_Tru...
# 21             1000  sarst_future_intervalC_0.5_inf_tanh_True_True_...
# 22             1000  sarst_future_intervalC_1_inf_tanh_True_True_10...
# 23             1000  sarst_future_intervalC_2_inf_linear_True_True_...
# 24             1000  sarst_future_intervalC_2_inf_tanh_True_True_10...
# 25             1200  sarst_future_intervalC_0.5_inf_linear_True_Tru...
# 26             1200  sarst_future_intervalC_0.5_inf_tanh_True_True_...
# 27             1200  sarst_future_intervalC_1_inf_tanh_True_True_10...
# 28             1200  sarst_future_intervalC_2_inf_linear_True_True_...
# 29             1200  sarst_future_intervalC_2_inf_tanh_True_True_10...
# ...             ...                                                ...
# 4970         199000  sarst_future_intervalC_0.5_inf_linear_True_Tru...
# 4971         199000  sarst_future_intervalC_0.5_inf_tanh_True_True_...
# 4972         199000  sarst_future_intervalC_1_inf_tanh_True_True_10...
# 4973         199000  sarst_future_intervalC_2_inf_linear_True_True_...
# 4974         199000  sarst_future_intervalC_2_inf_tanh_True_True_10...
# 4975         199200  sarst_future_intervalC_0.5_inf_linear_True_Tru...
# 4976         199200  sarst_future_intervalC_0.5_inf_tanh_True_True_...
# 4977         199200  sarst_future_intervalC_1_inf_tanh_True_True_10...
# 4978         199200  sarst_future_intervalC_2_inf_linear_True_True_...
# 4979         199200  sarst_future_intervalC_2_inf_tanh_True_True_10...
# 4980         199400  sarst_future_intervalC_0.5_inf_linear_True_Tru...
# 4981         199400  sarst_future_intervalC_0.5_inf_tanh_True_True_...
# 4982         199400  sarst_future_intervalC_1_inf_tanh_True_True_10...
# 4983         199400  sarst_future_intervalC_2_inf_linear_True_True_...
# 4984         199400  sarst_future_intervalC_2_inf_tanh_True_True_10...
# 4985         199600  sarst_future_intervalC_0.5_inf_linear_True_Tru...
# 4986         199600  sarst_future_intervalC_0.5_inf_tanh_True_True_...
# 4987         199600  sarst_future_intervalC_1_inf_tanh_True_True_10...
# 4988         199600  sarst_future_intervalC_2_inf_linear_True_True_...
# 4989         199600  sarst_future_intervalC_2_inf_tanh_True_True_10...
# 4990         199800  sarst_future_intervalC_0.5_inf_linear_True_Tru...
# 4991         199800  sarst_future_intervalC_0.5_inf_tanh_True_True_...
# 4992         199800  sarst_future_intervalC_1_inf_tanh_True_True_10...
# 4993         199800  sarst_future_intervalC_2_inf_linear_True_True_...
# 4994         199800  sarst_future_intervalC_2_inf_tanh_True_True_10...
# 4995         200000  sarst_future_intervalC_0.5_inf_linear_True_Tru...
# 4996         200000  sarst_future_intervalC_0.5_inf_tanh_True_True_...
# 4997         200000  sarst_future_intervalC_1_inf_tanh_True_True_10...
# 4998         200000  sarst_future_intervalC_2_inf_linear_True_True_...
# 4999         200000  sarst_future_intervalC_2_inf_tanh_True_True_10...
#
#       Test reward on initial goal  Test reward on random goal  critic_loss  \
# 0                             NaN                         NaN     0.000285
# 1                             NaN                         NaN     0.000289
# 2                             NaN                         NaN     0.000347
# 3                             NaN                         NaN     0.000471
# 4                             NaN                         NaN     0.000454
# 5                             NaN                         NaN     0.000037
# 6                             NaN                         NaN     0.000020
# 7                             NaN                         NaN     0.000021
# 8                             NaN                         NaN     0.000037
# 9                             NaN                         NaN     0.000030
# 10                            NaN                         NaN     0.000024
# 11                            NaN                         NaN     0.000013
# 12                            NaN                         NaN     0.000016
# 13                            NaN                         NaN     0.000043
# 14                            NaN                         NaN     0.000026
# 15                            NaN                         NaN     0.000003
# 16                            NaN                         NaN     0.000003
# 17                            NaN                         NaN     0.000003
# 18                            NaN                         NaN     0.000011
# 19                            NaN                         NaN     0.000011
# 20                      -0.008269                   -0.026173     0.135806
# 21                      -0.006719                   -0.217151     0.000004
# 22                      -0.009408                   -0.151984     0.000004
# 23                      -0.044179                   -0.353862     0.205326
# 24                      -0.046321                   -1.228115     0.000008
# 25                      -0.008269                   -0.026173     0.537954
# 26                      -0.006719                   -0.217151     0.000036
# 27                      -0.009408                   -0.151984     0.136424
# 28                      -0.044179                   -0.353862     0.179075
# 29                      -0.046321                   -1.228115     0.058895
# ...                           ...                         ...          ...
# 4970                    92.835631                   88.702519     0.572994
# 4971                    91.918939                   91.423248     0.493165
# 4972                    87.202448                   83.763906     0.494819
# 4993                0.114022      9.5
# 4994                0.097831      9.5
# 4995                0.151884      9.5
# 4996                0.131159      9.5
# 4997                0.111484      9.5
# 4998                0.121407      9.5
# 4999                0.100545      9.5
#
# [5000 rows x 11 columns]

# %%
means_steps['mean_Q_values'] = means_steps.groupby('params')['mean_Q_values'].apply(lambda x: x.ewm(5).mean())
fig, ax = plt.subplots(figsize=(18,10))
for name, g in means_steps.groupby(['params'])[['training_step','mean_Q_values']]:
    g.plot(x='training_step',y='mean_Q_values', label=name, ax=ax)

# %%
means_steps['mean_target_Q_values'] = means_steps.groupby('params')['mean_target_Q_values'].apply(lambda x: x.ewm(5).mean())
fig, ax = plt.subplots(figsize=(18,10))
for name, g in means_steps.groupby(['params'])[['training_step','mean_target_Q_values']]:
    g.plot(x='training_step',y='mean_target_Q_values', label=name, ax=ax)

# %%
means_steps['Test reward on initial goal'] = means_steps.groupby('params')['Test reward on initial goal'].apply(lambda x: x.ewm(5).mean())
fig, ax = plt.subplots(figsize=(18,10))
for name, g in means_steps.groupby(['params'])[['training_step','Test reward on initial goal']]:
    g.plot(x='training_step',y='Test reward on initial goal', label=name, ax=ax)

# %%
res_final = expe_res_steps[expe_res_steps['training_step']==200000]
fig, axes = plt.subplots(4,2, figsize=(24,10))
for i,(name, g) in enumerate(res_final.groupby('params')['Test reward on initial goal']):
    g.plot(kind='hist', title=name, ax=axes[i%4, i//4])

# %%
means_steps['Test reward on random goal'] = means_steps.groupby('params')['Test reward on random goal'].apply(lambda x: x.ewm(5).mean())
fig, ax = plt.subplots(figsize=(18,10))
for name, g in means_steps.groupby(['params'])[['training_step','Test reward on random goal']]:
    g.plot(x='training_step',y='Test reward on random goal', label=name, ax=ax)

# %%
fig, axes = plt.subplots(4,2, figsize=(24,10))
for i,(name, g) in enumerate(res_final.groupby('params')['Test reward on random goal']):
    g.plot(kind='hist', title=name, ax=axes[i%4, i//4])

# %%
import seaborn as sns
fig, axes = plt.subplots(len(PARAMS), figsize=(18,40))
expe_res_steps_0 = expe_res_steps[expe_res_steps['num_run']==0]
for i, (name, g) in enumerate(expe_res_steps_0.groupby('params')):
    q_vals = g['q_values'].apply(pd.Series)
    heatmap = q_vals.T
    heatmap.columns = range(200, 200001,200)
    sns.heatmap(heatmap, ax=axes[i], xticklabels = 200)
    axes[i].set_title(name)
    axes[i].set_yticklabels([list(np.linspace(-1.2, 0.6, 100))[int(label.get_text())] for label in axes[i].get_yticklabels()])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2521             try:
# -> 2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'q_values'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-95d910db651c> in <module>()
#       3 expe_res_steps_0 = expe_res_steps[expe_res_steps['num_run']==0]
#       4 for i, (name, g) in enumerate(expe_res_steps_0.groupby('params')):
# ----> 5     q_vals = g['q_values'].apply(pd.Series)
#       6     heatmap = q_vals.T
#       7     heatmap.columns = range(200, 200001,200)
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/.local/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/.local/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3836
#    3837             if not isna(item):
# -> 3838                 loc = self.items.get_loc(item)
#    3839             else:
#    3840                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
# -> 2524                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2525
#    2526         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'q_values'

# %%
import seaborn as sns
fig, axes = plt.subplots(len(PARAMS), figsize=(18,40))
expe_res_steps_0 = expe_res_steps[expe_res_steps['num_run']==0]
for i, (name, g) in enumerate(expe_res_steps_0.groupby('params')):
    q_vals = g['d_q_values'].apply(pd.Series)
    heatmap = q_vals.T
    heatmap.columns = range(200, 200001,200)
    sns.heatmap(heatmap, ax=axes[i], xticklabels = 200)
    axes[i].set_title(name)
    axes[i].set_yticklabels([list(np.linspace(-1.2, 0.6, 100))[int(label.get_text())] for label in axes[i].get_yticklabels()])

# %%
frames = []
for PARAM in PARAMS:
    res_episodes = glob.glob(LOGDIR + PARAM + '/*/' + 'log_episodes/progress.json')
    for num_run, run in enumerate(res_episodes):
        try:
            df = pd.read_json(run, lines=True)
        except ValueError:
            print("invalid")
        df['params'] = PARAM
        df['num_run']=num_run
        frames.append(df)
expe_res_episodes = pd.concat(frames, ignore_index=True)
expe_res_episodes
# Out:
#             Duration  Episode  Episode steps      Goal  Goal reached  \
# 0           2.428090        1            200  0.563636             0
# 1          15.202794        2            200  0.000000             0
# 2          30.219414        3            194 -0.927273             1
# 3          33.496388        4             38 -1.145455             2
# 4          50.151190        5            200 -1.127273             2
# 5          58.514455        6             99 -1.090909             3
# 6          84.976452        7            200 -0.109091             3
# 7          96.862887        8            144 -0.254545             4
# 8         113.217108        9            200 -0.181818             4
# 9         113.314449       10              1 -0.545455             5
# 10        113.479528       11              1 -0.509091             6
# 11        129.537895       12            200  0.527273             6
# 12        132.247614       13             36  0.072727             7
# 13        135.717635       14             40  0.036364             8
# 14        135.796412       15              1 -0.563636             9
# 15        152.049512       16            200  0.509091             9
# 16        178.633063       17            200  0.181818             9
# 17        180.328951       18             23 -0.945455            10
# 18        196.893742       19            200 -0.272727            10
# 19        206.200735       20            105 -0.345455            11
# 20        222.130083       21            200  0.127273            11
# 21        223.776919       22             19 -0.709091            12
# 22        223.852218       23              1 -0.563636            13
# 23        223.936127       24              1 -0.436364            14
# 24        238.880905       25            200 -1.145455            14
# 25        263.004720       26            200  0.327273            14
# 26        279.339914       27            200 -1.109091            14
# 27        296.496292       28            200 -1.200000            14
# 28        297.943372       29             15 -0.745455            15
# 29        313.873462       30            200 -0.018182            15
# ...              ...      ...            ...       ...           ...
# 486278  14745.626572     3314             54 -0.127273          2873
# 486279  14747.036439     3315             19 -0.327273          2874
# 486280  14761.044608     3316            200  0.454545          2874
# 486281  14764.906057     3317             50 -1.090909          2875
# 486282  14768.576016     3318             48 -1.090909          2876
# 486283  14783.194102     3319            200  0.290909          2876
# 486284  14796.135920     3320            200  0.472727          2876
# 486285  14799.502675     3321             54 -1.036364          2877
# 486286  14802.710186     3322             51 -1.036364          2878
# 486287  14815.774412     3323             97 -1.072727          2879
sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 1       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 2       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 3       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 4       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 5       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 6       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 7       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 8       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 9       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 10      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 11      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 12      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 13      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 14      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 15      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 16      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 17      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 18      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 19      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 20      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 21      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 22      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 23      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 24      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 25      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 26      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 27      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 28      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 29      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# ...                                              ...      ...
# 486278     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486279     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486280     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486281     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486282     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486283     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486284     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486285     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486286     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486287     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486288     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486289     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486290     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486291     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486292     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486293     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486294     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486295     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486296     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486297     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486298     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486299     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486300     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486301     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486302     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486303     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486304     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486305     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486306     sarst_final_comp_5_inf_tanh_True_True_200       19
# 486307     sarst_final_comp_5_inf_tanh_True_True_200       19
#
# [486308 rows x 10 columns]

# %%
expe_res_ep_plot
# Out:
#             Duration  Episode  Episode steps      Goal  Goal reached  \
# 0           2.428090        1            200  0.563636             0
# 1          15.202794        2            200  0.000000             0
# 2          30.219414        3            194 -0.927273             1
# 3          33.496388        4             38 -1.145455             2
# 4          50.151190        5            200 -1.127273             2
# 5          58.514455        6             99 -1.090909             3
# 6          84.976452        7            200 -0.109091             3
# 7          96.862887        8            144 -0.254545             4
# 8         113.217108        9            200 -0.181818             4
# 9         113.314449       10              1 -0.545455             5
# 10        113.479528       11              1 -0.509091             6
# 11        129.537895       12            200  0.527273             6
# 12        132.247614       13             36  0.072727             7
# 13        135.717635       14             40  0.036364             8
# 14        135.796412       15              1 -0.563636             9
# 15        152.049512       16            200  0.509091             9
# 16        178.633063       17            200  0.181818             9
# 17        180.328951       18             23 -0.945455            10
# 18        196.893742       19            200 -0.272727            10
# 19        206.200735       20            105 -0.345455            11
# 20        222.130083       21            200  0.127273            11
# 21        223.776919       22             19 -0.709091            12
# 22        223.852218       23              1 -0.563636            13
# 23        223.936127       24              1 -0.436364            14
# 24        238.880905       25            200 -1.145455            14
# 25        263.004720       26            200  0.327273            14
# 26        279.339914       27            200 -1.109091            14
# 27        296.496292       28            200 -1.200000            14
# 28        297.943372       29             15 -0.745455            15
# 29        313.873462       30            200 -0.018182            15
# ...              ...      ...            ...       ...           ...
# 413307  14922.008618     3337             26 -0.963636          2877
# 413308  14924.194440     3338             30 -1.018182          2878
# 413309  14925.818148     3339             27 -0.963636          2879
# 413310  14927.324144     3340             24 -0.963636          2880
# 413311  14934.234943     3341            113  0.218182          2881
# 413312  14938.695627     3342             69  0.236364          2882
# 413313  14940.282900     3343             30 -1.054545          2883
# 413314  14941.913461     3344             26 -0.981818          2884
# 413315  14943.668280     3345             31 -1.018182          2885
# 413316  14945.403219     3346             30 -1.036364          2886
# 413317  14946.930025     3347             28 -1.036364          2887
# 413318  14958.477771     3348            160  0.054545          2888
# 413319  14960.264400     3349             33 -1.018182          2889
sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 1       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 2       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 3       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 4       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 5       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 6       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 7       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 8       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 9       sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 10      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 11      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 12      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 13      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 14      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 15      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 16      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 17      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 18      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 19      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 20      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 21      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 22      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 23      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 24      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 25      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 26      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 27      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 28      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# 29      sarst_final_comp_0.1_inf_tanh_True_False_200        0
# ...                                              ...      ...
# 413307     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413308     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413309     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413310     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413311     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413312     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413313     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413314     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413315     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413316     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413317     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413318     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413319     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413320     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413321     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413322     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413323     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413324     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413325     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413326     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413327     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413328     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413329     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413330     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413331     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413332     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413333     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413334     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413335     sarst_final_comp_5_inf_tanh_True_True_200        0
# 413336     sarst_final_comp_5_inf_tanh_True_True_200        0
#
#           train_interval
# 0              (0, 1000]
# 1              (0, 1000]
# 2              (0, 1000]
# 3              (0, 1000]
# 4              (0, 1000]
# 5              (0, 1000]
# 6           (1000, 2000]
# 7           (1000, 2000]
# 8           (1000, 2000]
# 9           (1000, 2000]
# 10          (1000, 2000]
# 11          (1000, 2000]
# 12          (1000, 2000]
# 13          (1000, 2000]
# 14          (1000, 2000]
# 15          (1000, 2000]
# 16          (2000, 3000]
# 17          (2000, 3000]
# 18          (2000, 3000]
# 19          (2000, 3000]
# 20          (2000, 3000]
# 21          (2000, 3000]
# 22          (2000, 3000]
# 23          (2000, 3000]
# 24          (2000, 3000]
# 25          (3000, 4000]
# 26          (3000, 4000]
# 27          (3000, 4000]
# 28          (3000, 4000]
# 29          (3000, 4000]
# ...                  ...
# 413307  (197000, 198000]
# 413308  (197000, 198000]
# 413309  (197000, 198000]
# 413310  (197000, 198000]
# 413311  (197000, 198000]
# 413312  (197000, 198000]
# 413313  (197000, 198000]
# 413314  (197000, 198000]
# 413315  (197000, 198000]
# 413316  (197000, 198000]
# 413317  (197000, 198000]
# 413318  (198000, 199000]
# 413319  (198000, 199000]
# 413320  (198000, 199000]
# 413321  (198000, 199000]
# 413322  (198000, 199000]
# 413323  (198000, 199000]
# 413324  (198000, 199000]
# 413325  (198000, 199000]
# 413326  (199000, 200000]
# 413327  (199000, 200000]
# 413328  (199000, 200000]
# 413329  (199000, 200000]
# 413330  (199000, 200000]
# 413331  (199000, 200000]
# 413332  (199000, 200000]
# 413333  (199000, 200000]
# 413334  (199000, 200000]
# 413335  (199000, 200000]
# 413336  (199000, 200000]
#
# [22683 rows x 11 columns]

# %%
expe_res_ep_plot = expe_res_episodes[expe_res_episodes['num_run']==0]
fig, axes = plt.subplots(8, figsize=(18,40))
for i, (name, g) in enumerate(expe_res_ep_plot.groupby('params')):
    g.plot(x='Train step', y='Goal', label=name, ax=axes[i], kind='scatter')

# %%
fig, axes = plt.subplots(8, figsize=(18,40))
for i, (name, g) in enumerate(expe_res_episodes.groupby('params')):
    g.plot(x='Train step', y='Goal', label=name, ax=axes[i], kind='hist', bins=18)
