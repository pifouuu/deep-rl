# %%
import json
import numpy as np
from eval_actor import Evaluator
import os

# %%
path = "../actors/"
collec = Evaluator()
for actor in os.listdir(path):
    collec.eval(actor)
# Out:
# 900  files found
# 0.1 :
#     nb conv :  2
#     nb div :  1
#     nb noconv :  97
#     total :  100
# 20.0 :
#     nb conv :  8
#     nb div :  1
#     nb noconv :  91
#     total :  100
# 5.0 :
#     nb conv :  4
#     nb div :  2
#     nb noconv :  94
#     total :  100
# 0.5 :
#     nb conv :  8
#     nb div :  2
#     nb noconv :  90
#     total :  100
# 100.0 :
#     nb conv :  8
#     nb div :  0
#     nb noconv :  92
#     total :  100
# 10.0 :
#     nb conv :  4
#     nb div :  0
#     nb noconv :  96
#     total :  100
# 1.0 :
#     nb conv :  8
#     nb div :  2
#     nb noconv :  90
#     total :  100
# 50.0 :
#     nb conv :  4
#     nb div :  1
#     nb noconv :  95
#     total :  100
# 15.0 :
#     nb conv :  10
#     nb div :  1
#     nb noconv :  89
#     total :  100
